# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaMidhath/PYTHON-DA-ML/blob/main/alina_day8_asst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT
#
# homework on two dataframes

# %%
import pandas as pd
import numpy as np
exam_data ={'name':['Anastasia', 'Dima','Katherine','James','Emily','Michel','Mathew','Laura','Kevin','Jonas'],
            'score':[12.5, 9.0,16.5, np.nan, 9.0, 20.0, 14.5, np.nan, 8.0, 19.0],
            'attempts':[1,3,2,3,2,3,1,1,2,1],
            'qualify':['yes','no','yes','no','no','yes','yes','no','no','yes']}
labels=['a','b','c','d','e','f','g','h','i','j']
ed = pd.DataFrame(exam_data, index=labels)
ed
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f     Michel   20.0         3     yes
# g     Mathew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#print only the name and score col
a = ed[['name','score']]
a
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f     Michel   20.0
# g     Mathew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
#print first three rows
x = ed.head(3)
x
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
#to print the no of rows and cols
row , col = ed.shape
print('the no of rows are: ',row)
print('the no of cols are: ',col)
# Out:
# the no of rows are:  10
# the no of cols are:  4

# %%
#to print select rows wherre no of atempts are less than 2 and score greater than 15
b = ed.loc[(ed.attempts <2)& (ed.score > 15)]
b
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
#tochange the score in row d
ed.score[3] = 11.5
ed
# Out:
# <ipython-input-33-a13afa161914>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ed.score[3] = 11.5
#         name  score  attempts qualify  new     r       mean
# a  Anastasia   12.5         1     yes    0  11.5  13.333333
# b       Dima    9.0         3      no    0  11.5  13.333333
# c  Katherine   16.5         2     yes    0  11.5  13.333333
# d      James   11.5         3      no    0  11.5  13.333333
# e      Emily    9.0         2      no    0  11.5  13.333333
# f     Michel   20.0         3     yes    0  11.5  13.333333
# g     Mathew   14.5         1     yes    0  11.5  13.333333
# h      Laura    NaN         1      no    0  11.5  13.333333
# i      Kevin    8.0         2      no    0  11.5  13.333333
# j      Jonas   19.0         1     yes    0  11.5  13.333333

# %%
ed.drop('r',axis=1,inplace=True)
ed
# Out:
#         name  score  attempts qualify  new       mean
# a  Anastasia   12.5         1     yes    0  13.333333
# b       Dima    9.0         3      no    0  13.333333
# c  Katherine   16.5         2     yes    0  13.333333
# d      James   11.5         3      no    0  13.333333
# e      Emily    9.0         2      no    0  13.333333
# f     Michel   20.0         3     yes    0  13.333333
# g     Mathew   14.5         1     yes    0  13.333333
# h      Laura    NaN         1      no    0  13.333333
# i      Kevin    8.0         2      no    0  13.333333
# j      Jonas   19.0         1     yes    0  13.333333

# %%
#to calc the sum of attempts
ed['attempts'].sum()
# Out:
# 19

# %%
ed['mean']=ed['score'].mean()
ed
# Out:
#         name  score  attempts qualify  new       mean
# a  Anastasia   12.5         1     yes    0  13.333333
# b       Dima    9.0         3      no    0  13.333333
# c  Katherine   16.5         2     yes    0  13.333333
# d      James   11.5         3      no    0  13.333333
# e      Emily    9.0         2      no    0  13.333333
# f     Michel   20.0         3     yes    0  13.333333
# g     Mathew   14.5         1     yes    0  13.333333
# h      Laura    NaN         1      no    0  13.333333
# i      Kevin    8.0         2      no    0  13.333333
# j      Jonas   19.0         1     yes    0  13.333333

# %%
#to insert a new row
ed.loc[len(ed.index)]=['Alina', 20 , 1 , 'yes',0,0]
ed
# Out:
#          name  score  attempts qualify  new       mean
# a   Anastasia   12.5         1     yes    0  13.333333
# b        Dima    9.0         3      no    0  13.333333
# c   Katherine   16.5         2     yes    0  13.333333
# d       James   11.5         3      no    0  13.333333
# e       Emily    9.0         2      no    0  13.333333
# f      Michel   20.0         3     yes    0  13.333333
# g      Mathew   14.5         1     yes    0  13.333333
# h       Laura    NaN         1      no    0  13.333333
# i       Kevin    8.0         2      no    0  13.333333
# j       Jonas   19.0         1     yes    0  13.333333
# 10      Alina   20.0         1     yes    0   0.000000

# %%
#deleting the newly added row
ed.drop(10,axis=0,inplace=True)
ed
# Out:
#         name  score  attempts qualify  new       mean
# a  Anastasia   12.5         1     yes    0  13.333333
# b       Dima    9.0         3      no    0  13.333333
# c  Katherine   16.5         2     yes    0  13.333333
# d      James   11.5         3      no    0  13.333333
# e      Emily    9.0         2      no    0  13.333333
# f     Michel   20.0         3     yes    0  13.333333
# g     Mathew   14.5         1     yes    0  13.333333
# h      Laura    NaN         1      no    0  13.333333
# i      Kevin    8.0         2      no    0  13.333333
# j      Jonas   19.0         1     yes    0  13.333333

# %%
#to sort names in acsending order
ed.sort_values(by='name')
# Out:
#         name  score  attempts qualify  new       mean
# a  Anastasia   12.5         1     yes    0  13.333333
# b       Dima    9.0         3      no    0  13.333333
# e      Emily    9.0         2      no    0  13.333333
# d      James   11.5         3      no    0  13.333333
# j      Jonas   19.0         1     yes    0  13.333333
# c  Katherine   16.5         2     yes    0  13.333333
# i      Kevin    8.0         2      no    0  13.333333
# h      Laura    NaN         1      no    0  13.333333
# g     Mathew   14.5         1     yes    0  13.333333
# f     Michel   20.0         3     yes    0  13.333333

# %%
ed.sort_values(by='score')
# Out:
#         name  score  attempts qualify  new       mean
# i      Kevin    8.0         2      no    0  13.333333
# b       Dima    9.0         3      no    0  13.333333
# e      Emily    9.0         2      no    0  13.333333
# d      James   11.5         3      no    0  13.333333
# a  Anastasia   12.5         1     yes    0  13.333333
# g     Mathew   14.5         1     yes    0  13.333333
# c  Katherine   16.5         2     yes    0  13.333333
# j      Jonas   19.0         1     yes    0  13.333333
# f     Michel   20.0         3     yes    0  13.333333
# h      Laura    NaN         1      no    0  13.333333

# %%
#to replace yes and no in qualify col with true and false
ed= ed.replace('no','false')
ed = ed.replace('yes','true')
ed
# Out:
#         name  score  attempts qualify  new       mean
# a  Anastasia   12.5         1    true    0  13.333333
# b       Dima    9.0         3   false    0  13.333333
# c  Katherine   16.5         2    true    0  13.333333
# d      James   11.5         3   false    0  13.333333
# e      Emily    9.0         2   false    0  13.333333
# f     Michel   20.0         3    true    0  13.333333
# g     Mathew   14.5         1    true    0  13.333333
# h      Laura    NaN         1   false    0  13.333333
# i      Kevin    8.0         2   false    0  13.333333
# j      Jonas   19.0         1    true    0  13.333333

# %%
#changing the name james to suresh
ed = ed.replace('James','suresh')
ed
# Out:
#         name  score  attempts qualify  new       mean
# a  Anastasia   12.5         1    true    0  13.333333
# b       Dima    9.0         3   false    0  13.333333
# c  Katherine   16.5         2    true    0  13.333333
# d     suresh   11.5         3   false    0  13.333333
# e      Emily    9.0         2   false    0  13.333333
# f     Michel   20.0         3    true    0  13.333333
# g     Mathew   14.5         1    true    0  13.333333
# h      Laura    NaN         1   false    0  13.333333
# i      Kevin    8.0         2   false    0  13.333333
# j      Jonas   19.0         1    true    0  13.333333

# %%
#deleting attempts col
ed.drop('attempts' , axis=1, inplace=True)
ed
# Out:
#         name  score qualify  new       mean
# a  Anastasia   12.5    true    0  13.333333
# b       Dima    9.0   false    0  13.333333
# c  Katherine   16.5    true    0  13.333333
# d     suresh   11.5   false    0  13.333333
# e      Emily    9.0   false    0  13.333333
# f     Michel   20.0    true    0  13.333333
# g     Mathew   14.5    true    0  13.333333
# h      Laura    NaN   false    0  13.333333
# i      Kevin    8.0   false    0  13.333333
# j      Jonas   19.0    true    0  13.333333

# %%
#to insert a new col
ed['new']= 0
ed
# Out:
#         name  score  attempts qualify  new
# a  Anastasia   12.5         1     yes    0
# b       Dima    9.0         3      no    0
# c  Katherine   16.5         2     yes    0
# d      James    NaN         3      no    0
# e      Emily    9.0         2      no    0
# f     Michel   20.0         3     yes    0
# g     Mathew   14.5         1     yes    0
# h      Laura    NaN         1      no    0
# i      Kevin    8.0         2      no    0
# j      Jonas   19.0         1     yes    0

# %%
#iterating over rows
for x in ed.index:
  print(ed['name'][x],ed['score'][x])

#look for more ways at geeksforgeeks
# Out:
# Anastasia 12.5
# Dima 9.0
# Katherine 16.5
# suresh 11.5
# Emily 9.0
# Michel 20.0
# Mathew 14.5
# Laura nan
# Kevin 8.0
# Jonas 19.0

# %%
#calc the no. of nan values
ed.isnull().sum()
# Out:
# name       0
# score      1
# qualify    0
# new        0
# mean       0
# dtype: int64

# %%
#changing the col names to uppper case
ed.rename(columns=str.upper)
# Out:
#         NAME  SCORE QUALIFY  NEW       MEAN
# a  Anastasia   12.5    true    0  13.333333
# b       Dima    9.0   false    0  13.333333
# c  Katherine   16.5    true    0  13.333333
# d     suresh   11.5   false    0  13.333333
# e      Emily    9.0   false    0  13.333333
# f     Michel   20.0    true    0  13.333333
# g     Mathew   14.5    true    0  13.333333
# h      Laura    NaN   false    0  13.333333
# i      Kevin    8.0   false    0  13.333333
# j      Jonas   19.0    true    0  13.333333

# %%
#adding under score
ed.add_prefix('_')
# Out:
#        _name  _score _qualify  _new      _mean
# a  Anastasia    12.5     true     0  13.333333
# b       Dima     9.0    false     0  13.333333
# c  Katherine    16.5     true     0  13.333333
# d     suresh    11.5    false     0  13.333333
# e      Emily     9.0    false     0  13.333333
# f     Michel    20.0     true     0  13.333333
# g     Mathew    14.5     true     0  13.333333
# h      Laura     NaN    false     0  13.333333
# i      Kevin     8.0    false     0  13.333333
# j      Jonas    19.0     true     0  13.333333

# %% [markdown]
# 2nd data set

# %%
d={'col1':[1,2,3],
   'col2':[4,5,6],
   'col3':[7,8,9]}
d = pd.DataFrame(d)
d
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
x = d.loc[d.isin([4]).any(axis=1)]
print(x)
# Out:
#    col1  col2  col3
# 0     1     4     7

# %%
print(d[d.columns[: : -1]])
# Out:
#    col3  col2  col1
# 0     7     4     1
# 1     8     5     2
# 2     9     6     3

# %%
d.loc[len(d.index)]=[10,11,12]
print(d)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# 3    10    11    12

# %%
d.drop(3,axis=0,inplace=True)
d
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
